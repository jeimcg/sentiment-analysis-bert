# %%
# tokenizing dataset

# %%
from transformers import XLNetTokenizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import XLNetTokenizer, XLNetForSequenceClassification, Trainer, TrainingArguments
#
# ModuleNotFoundError: No module named 'transformers'

# %%
tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased')

# %%
def tokenize_text(file_path):
    with open(file_path, "r") as f:
        lines = f.readlines()
    tokenized = [tokenizer(line, truncation=True, padding="max_length", max_length=512)["input_ids"] for line in lines]
    return tokenized

tokenized_data = tokenize_text("lyrics_dataset.txt")

# %%
from datasets import Dataset
raw_dataset = Dataset.from_dict({"text": lyrics.tolist()})
tokenized_dataset = raw_dataset.map(tokenize_function, batched=True)

# %%
# pretraining dataset

# %%
from transformers import XLNetForSequenceClassification, Trainer, TrainingArguments

# %%
model = XLNetForSequenceClassification.from_pretrained("xlnet-base-cased", num_labels=2)

# %%
training_args - TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size = 8,
    num_train_epochs = 3,
    save_steps = 500,
    logging_dir="./logs"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)

# %%
trainer.train()

# %%
model.save_pretrained("./lyrics_xlnet_model")
tokenizer.save_pretrained("./lyrics_xlnet_model")

# %%
# decicded to do in colab bc of processing capabilities on my college macbook lol
